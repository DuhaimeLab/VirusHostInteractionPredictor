# %% [markdown]
# # Example of running VHIP

# %% [markdown]
# ## Running VHIP
#
# Imports

# %%
from vhip.mlmodel.build import BuildModel
from vhip.predict_interactions import PredictInteractions

# %% [markdown]
# There are two steps to run VHIP:
# 1. Building the machine learning model (using best parameters)
# 2. Applying model on data of interest
#
# In this notebook, the entire pipeline is demonstrated. If you are interested in running VHIP on your own, please make sure you can run this notebook with the given example first to ensure the VHIP module was properly installed.

# %% [markdown]
# ### 1. Retrain the machine learning model
#
# The first step is to retrain the machine learning model using the best hyperparameters as explored in the VHIP manuscript.

# %%
ml_training = "./ml_input.csv"

model = BuildModel(ml_training)
VHIP = model.build()
# Out:
# The dataframe is made of 6925 rows and 4 columns!
# Accuracy on training set: 1.000
# Accuracy on test set: 0.879

# %% [markdown]
# Now that the model is loaded and trained, we can apply it to new datasets.
#
# For the input, you will need:
# 1. the directory of virus sequences. Each file should represent an unique virus.
# 2. The directory of host sequences. Each file should represent an unique host.
# 3. The blastn between virus sequences and host sequences.
# 4. The blastn between virus sequences and host spacers.

# %%
virus_genomes_directory_path = "./virus_genomes/"
host_genomes_directory_path = "./host_genomes/"
virus_genes_directory_path = "./virus_genes/"
host_genes_directory_path = "./host_genes/"
blastn_path = "./StaphStudy_virusvhosts.tsv"
spacer_path = "./StaphStudy_virusvspacers_blastn.tsv"

# %% [markdown]
# In addition, let's also define the name of the output and the number of CPU cores to be used.

# %%
output_filename = "./predictions.tsv"
CPU_CORES = 6

# %% [markdown]
# ### 2. Run model

# %%
predictions = PredictInteractions(
    virus_genomes_directory_path,
    host_genomes_directory_path,
    virus_genes_directory_path,
    host_genes_directory_path,
)
predictions.model = VHIP
predictions.add_blastn_files(blastn_path, spacer_path)
predictions.do_setup()
predictions.run_parallel(CPU_CORES)
predictions.predict()
predictions.save_predictions(output_filename)
# Out:
# SETUP - ...indexing genome fasta filenames for viruses and hosts...
# SETUP - ...indexing annotated gene fasta filenames for viruses and hosts...
# SETUP - ...initialize all pairs...
# -------> There are 40 viral sequences
# -------> There are 27 host sequences
# -------> Total number of interactions: 1080
# SETUP - ...getting fasta headers...
# SETUP - ...process blastn and spacers output...
# SETUP - ...calculate GC content and k-mer profiles...
# SETUP - ...calculate codon and amino acid profiles...
# 1.4705882352941175% (3/204) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.904977375565611% (2/221) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.4492753623188406% (3/207) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.0% (0/212) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.0% (0/72) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.097902097902098% (3/143) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.0% (0/69) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.4354066985645932% (3/209) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.4492753623188406% (3/207) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.4634146341463417% (3/205) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.0% (0/211) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.0% (0/201) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.0% (0/188) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.9803921568627451% (2/204) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.975609756097561% (2/205) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.0% (0/72) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.975609756097561% (2/205) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.9174311926605505% (2/218) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.3157894736842104% (3/228) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.7518796992481203% (1/133) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.0% (0/204) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.0% (0/214) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.4634146341463417% (3/205) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.4634146341463417% (3/205) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.112676056338028% (3/142) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.4285714285714286% (3/210) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.8130081300813009% (1/123) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.0% (0/66) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.097902097902098% (3/143) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.015228426395939% (2/197) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.7936507936507936% (1/126) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.4354066985645932% (3/209) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.4563106796116505% (3/206) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.9803921568627451% (2/204) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.9950248756218906% (2/201) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.975609756097561% (2/205) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 1.06951871657754% (2/187) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.7462686567164178% (1/134) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.0% (0/205) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 0.9523809523809524% (2/210) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 4.704974932510606% (122/2593) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 3.000447828034035% (67/2233) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 3.025540275049116% (77/2545) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.801003344481605% (67/2392) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.916346891788181% (76/2606) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 3.5910589959692194% (98/2729) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 4.50112528132033% (120/2666) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.345495160089352% (63/2686) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 3.0164533820840953% (66/2188) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.6824457593688362% (68/2535) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.759343346140412% (79/2863) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.711864406779661% (72/2655) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 3.038897893030794% (75/2468) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.576112412177986% (66/2562) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.841918294849023% (80/2815) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.663337494798169% (64/2403) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 3.166730255627623% (83/2621) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.8527957398250288% (75/2629) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 3.4782608695652173% (84/2415) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.806324110671937% (71/2530) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.912621359223301% (78/2678) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.2984028048305416% (59/2567) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 3.043308622707764% (78/2563) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.5955804980708526% (74/2851) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.585841458245019% (61/2359) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.4875621890547266% (130/5226) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# 2.454873646209386% (68/2770) of genes skipped. Expect on average ~2% and ~3% of virus and host genes (respectively) to be skipped on the basis of non-divisibility by codon length.
# Analyzing gene 1 of 201
# Analyzing gene 2 of 201
# Analyzing gene 3 of 201
# Analyzing gene 4 of 201
# Analyzing gene 5 of 201
# Analyzing gene 6 of 201
# Analyzing gene 7 of 201
# Analyzing gene 8 of 201
# Analyzing gene 9 of 201
# Analyzing gene 10 of 201
# Analyzing gene 11 of 201
# Analyzing gene 12 of 201
# Analyzing gene 13 of 201
# Analyzing gene 14 of 201
# Analyzing gene 15 of 201
# Analyzing gene 16 of 201
# Analyzing gene 17 of 201
# Analyzing gene 18 of 201
# Analyzing gene 19 of 201
# Analyzing gene 20 of 201
# Analyzing gene 21 of 201
# Analyzing gene 22 of 201
# Analyzing gene 23 of 201
# Analyzing gene 24 of 201
# Analyzing gene 25 of 201
# Analyzing gene 26 of 201
# Analyzing gene 27 of 201
# Analyzing gene 28 of 201
# Analyzing gene 29 of 201
# Analyzing gene 30 of 201
# Analyzing gene 31 of 201
# Analyzing gene 32 of 201
# Analyzing gene 33 of 201
# Analyzing gene 34 of 201
# Analyzing gene 35 of 201
# Analyzing gene 36 of 201
# Analyzing gene 37 of 201
# Analyzing gene 38 of 201
# Analyzing gene 39 of 201
# Analyzing gene 40 of 201
# Analyzing gene 41 of 201
# Analyzing gene 42 of 201
# Analyzing gene 43 of 201
# Analyzing gene 44 of 201
# Analyzing gene 45 of 201
# Analyzing gene 46 of 201
# Analyzing gene 47 of 201
# Analyzing gene 48 of 201
# Analyzing gene 49 of 201
# Analyzing gene 50 of 201
# Analyzing gene 51 of 201
# Analyzing gene 52 of 201
# Analyzing gene 53 of 201
# Analyzing gene 54 of 201
# Analyzing gene 55 of 201
# Analyzing gene 56 of 201
# Analyzing gene 57 of 201
# Analyzing gene 58 of 201
# Analyzing gene 59 of 201
# Analyzing gene 60 of 201
# Analyzing gene 61 of 201
# Analyzing gene 62 of 201
# Analyzing gene 63 of 201
# Analyzing gene 64 of 201
# Analyzing gene 65 of 201
# Analyzing gene 66 of 201
# Analyzing gene 67 of 201
# Analyzing gene 68 of 201
# Analyzing gene 69 of 201
# Analyzing gene 70 of 201
# Analyzing gene 71 of 201
# Analyzing gene 72 of 201
# Analyzing gene 73 of 201
# Analyzing gene 74 of 201
# Analyzing gene 75 of 201
# Analyzing gene 76 of 201
# Analyzing gene 77 of 201
# Analyzing gene 78 of 201
# Analyzing gene 79 of 201
# Analyzing gene 80 of 201
# Analyzing gene 81 of 201
# Analyzing gene 82 of 201
# Analyzing gene 83 of 201
# Analyzing gene 84 of 201
# Analyzing gene 85 of 201
# Analyzing gene 86 of 201
# Analyzing gene 87 of 201
# Analyzing gene 88 of 201
# Analyzing gene 89 of 201
# Analyzing gene 90 of 201
# Analyzing gene 91 of 201
# Analyzing gene 92 of 201
# Analyzing gene 93 of 201
# Analyzing gene 94 of 201
# Analyzing gene 95 of 201
# Analyzing gene 96 of 201
# Analyzing gene 97 of 201
# Analyzing gene 98 of 201
# Analyzing gene 99 of 201
# Analyzing gene 100 of 201
# Analyzing gene 101 of 201
# Analyzing gene 102 of 201
# Analyzing gene 103 of 201
# Analyzing gene 104 of 201
# Analyzing gene 105 of 201
# Analyzing gene 106 of 201
# Analyzing gene 107 of 201
# Analyzing gene 108 of 201
# Analyzing gene 109 of 201
# Analyzing gene 110 of 201
# Analyzing gene 111 of 201
# Analyzing gene 112 of 201
# Analyzing gene 113 of 201
# Analyzing gene 114 of 201
# Analyzing gene 115 of 201
# Analyzing gene 116 of 201
# Analyzing gene 117 of 201
# Analyzing gene 118 of 201
# Analyzing gene 119 of 201
# Analyzing gene 120 of 201
# Analyzing gene 121 of 201
# Analyzing gene 122 of 201
# Analyzing gene 123 of 201
# Analyzing gene 124 of 201
# Analyzing gene 125 of 201
# Analyzing gene 126 of 201
# Analyzing gene 127 of 201
# Analyzing gene 128 of 201
# Analyzing gene 129 of 201
# Analyzing gene 130 of 201
# Analyzing gene 131 of 201
# Analyzing gene 132 of 201
# Analyzing gene 133 of 201
# Analyzing gene 134 of 201
# Analyzing gene 135 of 201
# Analyzing gene 136 of 201
# Analyzing gene 137 of 201
# Analyzing gene 138 of 201
# Analyzing gene 139 of 201
# Analyzing gene 140 of 201
# Analyzing gene 141 of 201
# Analyzing gene 142 of 201
# Analyzing gene 143 of 201
# Analyzing gene 144 of 201
# Analyzing gene 145 of 201
# Analyzing gene 146 of 201
# Analyzing gene 147 of 201
# Analyzing gene 148 of 201
# Analyzing gene 149 of 201
# Analyzing gene 150 of 201
# Analyzing gene 151 of 201
# Analyzing gene 152 of 201
# Analyzing gene 153 of 201
# Analyzing gene 154 of 201
# Analyzing gene 155 of 201
# Analyzing gene 156 of 201
# Analyzing gene 157 of 201
# Analyzing gene 158 of 201
# Analyzing gene 159 of 201
# Analyzing gene 160 of 201
# Analyzing gene 43 of 204
# Analyzing gene 44 of 204
# Analyzing gene 45 of 204
# Analyzing gene 46 of 204
# Analyzing gene 47 of 204
# Analyzing gene 48 of 204
# Analyzing gene 49 of 204
# Analyzing gene 50 of 204
# Analyzing gene 51 of 204
# Analyzing gene 52 of 204
# Analyzing gene 53 of 204
# Analyzing gene 54 of 204
# Analyzing gene 55 of 204
# Analyzing gene 56 of 204
# Analyzing gene 57 of 204
# Analyzing gene 58 of 204
# Analyzing gene 59 of 204
# Analyzing gene 60 of 204
# Analyzing gene 61 of 204
# Analyzing gene 62 of 204
# Analyzing gene 63 of 204
# Analyzing gene 64 of 204
# Analyzing gene 65 of 204
# Analyzing gene 66 of 204
# Analyzing gene 67 of 204
# Analyzing gene 68 of 204
# Analyzing gene 69 of 204
# Analyzing gene 70 of 204
# Analyzing gene 71 of 204
# Analyzing gene 72 of 204
# Analyzing gene 73 of 204
# Analyzing gene 74 of 204
# Analyzing gene 75 of 204
# Analyzing gene 76 of 204
# Analyzing gene 77 of 204
# Analyzing gene 78 of 204
# Analyzing gene 79 of 204
# Analyzing gene 80 of 204
# Analyzing gene 81 of 204
# Analyzing gene 82 of 204
# Analyzing gene 83 of 204
# Analyzing gene 84 of 204
# Analyzing gene 85 of 204
# Analyzing gene 86 of 204
# Analyzing gene 87 of 204
# Analyzing gene 88 of 204
# Analyzing gene 89 of 204
# Analyzing gene 90 of 204
# Analyzing gene 91 of 204
# Analyzing gene 92 of 204
# Analyzing gene 93 of 204
# Analyzing gene 94 of 204
# Analyzing gene 95 of 204
# Analyzing gene 96 of 204
# Analyzing gene 97 of 204
# Analyzing gene 98 of 204
# Analyzing gene 99 of 204
# Analyzing gene 100 of 204
# Analyzing gene 101 of 204
# Analyzing gene 102 of 204
# Analyzing gene 103 of 204
# Analyzing gene 104 of 204
# Analyzing gene 105 of 204
# Analyzing gene 106 of 204
# Analyzing gene 107 of 204
# Analyzing gene 108 of 204
# Analyzing gene 109 of 204
# Analyzing gene 110 of 204
# Analyzing gene 111 of 204
# Analyzing gene 112 of 204
# Analyzing gene 113 of 204
# Analyzing gene 114 of 204
# Analyzing gene 115 of 204
# Analyzing gene 116 of 204
# Analyzing gene 117 of 204
# Analyzing gene 118 of 204
# Analyzing gene 119 of 204
# Analyzing gene 120 of 204
# Analyzing gene 121 of 204
# Analyzing gene 122 of 204
# Analyzing gene 123 of 204
# Analyzing gene 124 of 204
# Analyzing gene 125 of 204
# Analyzing gene 126 of 204
# Analyzing gene 127 of 204
# Analyzing gene 128 of 204
# Analyzing gene 129 of 204
# Analyzing gene 130 of 204
# Analyzing gene 131 of 204
# Analyzing gene 132 of 204
# Analyzing gene 133 of 204
# Analyzing gene 134 of 204
# Analyzing gene 135 of 204
# Analyzing gene 136 of 204
# Analyzing gene 137 of 204
# Analyzing gene 138 of 204
# Analyzing gene 139 of 204
# Analyzing gene 140 of 204
# Analyzing gene 141 of 204
# Analyzing gene 142 of 204
# Analyzing gene 143 of 204
# Analyzing gene 144 of 204
# Analyzing gene 145 of 204
# Analyzing gene 146 of 204
# Analyzing gene 147 of 204
# Analyzing gene 148 of 204
# Analyzing gene 149 of 204
# Analyzing gene 150 of 204
# Analyzing gene 151 of 204
# Analyzing gene 152 of 204
# Analyzing gene 153 of 204
# Analyzing gene 154 of 204
# Analyzing gene 155 of 204
# Analyzing gene 156 of 204
# Analyzing gene 157 of 204
# Analyzing gene 158 of 204
# Analyzing gene 159 of 204
# Analyzing gene 160 of 204
# Analyzing gene 161 of 204
# Analyzing gene 162 of 204
# Analyzing gene 163 of 204
# Analyzing gene 164 of 204
# Analyzing gene 165 of 204
# Analyzing gene 166 of 204
# Analyzing gene 167 of 204
# Analyzing gene 168 of 204
# Analyzing gene 169 of 204
# Analyzing gene 170 of 204
# Analyzing gene 171 of 204
# Analyzing gene 172 of 204
# Analyzing gene 173 of 204
# Analyzing gene 174 of 204
# Analyzing gene 175 of 204
# Analyzing gene 176 of 204
# Analyzing gene 177 of 204
# Analyzing gene 178 of 204
# Analyzing gene 179 of 204
# Analyzing gene 180 of 204
# Analyzing gene 181 of 204
# Analyzing gene 182 of 204
# Analyzing gene 183 of 204
# Analyzing gene 184 of 204
# Analyzing gene 185 of 204
# Analyzing gene 186 of 204
# Analyzing gene 187 of 204
# Analyzing gene 188 of 204
# Analyzing gene 189 of 204
# Analyzing gene 190 of 204
# Analyzing gene 191 of 204
# Analyzing gene 192 of 204
# Analyzing gene 193 of 204
# Analyzing gene 194 of 204
# Analyzing gene 195 of 204
# Analyzing gene 196 of 204
# Analyzing gene 197 of 204
# Analyzing gene 198 of 204
# Analyzing gene 199 of 204
# Analyzing gene 200 of 204
# Analyzing gene 201 of 204
# Analyzing gene 202 of 204
# Analyzing gene 203 of 204
# Analyzing gene 204 of 204
# Analyzing gene 1 of 212
# Analyzing gene 2 of 212
# Analyzing gene 3 of 212
# Analyzing gene 4 of 212
# Analyzing gene 5 of 212
# Analyzing gene 6 of 212
# Analyzing gene 7 of 212
# Analyzing gene 8 of 212
# Analyzing gene 9 of 212
# Analyzing gene 10 of 212
# Analyzing gene 11 of 212
# Analyzing gene 12 of 212
# Analyzing gene 13 of 212
# Analyzing gene 14 of 212
# Analyzing gene 15 of 212
# Analyzing gene 16 of 212
# Analyzing gene 17 of 212
# Analyzing gene 18 of 212
# Analyzing gene 19 of 212
# Analyzing gene 20 of 212
# Analyzing gene 21 of 212
# Analyzing gene 22 of 212
# Analyzing gene 23 of 212
# Analyzing gene 24 of 212
# Analyzing gene 25 of 212
# Analyzing gene 26 of 212
# Analyzing gene 27 of 212
# Analyzing gene 28 of 212
# Analyzing gene 29 of 212
# Analyzing gene 30 of 212
# Analyzing gene 31 of 212
# Analyzing gene 32 of 212
# Analyzing gene 33 of 212
# Analyzing gene 34 of 212
# Analyzing gene 35 of 212
# Analyzing gene 36 of 212
# Analyzing gene 37 of 212
# Analyzing gene 38 of 212
# Analyzing gene 39 of 212
# Analyzing gene 40 of 212
# Analyzing gene 41 of 212
# Analyzing gene 42 of 212
# Analyzing gene 43 of 212
# Analyzing gene 44 of 212
# Analyzing gene 45 of 212
# Analyzing gene 46 of 212
# Analyzing gene 47 of 212
# Analyzing gene 48 of 212
# Analyzing gene 49 of 212
# Analyzing gene 50 of 212
# Analyzing gene 51 of 212
# Analyzing gene 52 of 212
# Analyzing gene 53 of 212
# Analyzing gene 54 of 212
# Analyzing gene 55 of 212
# Analyzing gene 56 of 212
# Analyzing gene 57 of 212
# Analyzing gene 58 of 212
# Analyzing gene 59 of 212
# Analyzing gene 60 of 212
# Analyzing gene 61 of 212
# Analyzing gene 62 of 212
# Analyzing gene 63 of 212
# Analyzing gene 64 of 212
# Analyzing gene 65 of 212
# Analyzing gene 66 of 212
# Analyzing gene 67 of 212
# Analyzing gene 68 of 212
# Analyzing gene 69 of 212
# Analyzing gene 70 of 212
# Analyzing gene 71 of 212
# Analyzing gene 72 of 212
# Analyzing gene 73 of 212
# Analyzing gene 74 of 212
# Analyzing gene 75 of 212
# Analyzing gene 76 of 212
# Analyzing gene 77 of 212
# Analyzing gene 78 of 212
# Analyzing gene 79 of 212
# Analyzing gene 80 of 212
# Analyzing gene 81 of 212
# Analyzing gene 82 of 212
# Analyzing gene 83 of 212
# Analyzing gene 84 of 212
# Analyzing gene 85 of 212
# Analyzing gene 86 of 212
# Analyzing gene 87 of 212
# Analyzing gene 88 of 212
# Analyzing gene 89 of 212
# Analyzing gene 90 of 212
# Analyzing gene 91 of 212
# Analyzing gene 92 of 212
# Analyzing gene 93 of 212
# Analyzing gene 94 of 212
# Analyzing gene 95 of 212
# Analyzing gene 96 of 212
# Analyzing gene 97 of 212
# Analyzing gene 98 of 212
# Analyzing gene 99 of 212
# Analyzing gene 100 of 212
# Analyzing gene 101 of 212
# Analyzing gene 102 of 212
# Analyzing gene 103 of 212
# Analyzing gene 104 of 212
# Analyzing gene 105 of 212
# Analyzing gene 106 of 212
# Analyzing gene 107 of 212
# Analyzing gene 108 of 212
# Analyzing gene 109 of 212
# Analyzing gene 110 of 212
# Analyzing gene 111 of 212
# Analyzing gene 112 of 212
# Analyzing gene 113 of 212
# Analyzing gene 114 of 212
# Analyzing gene 115 of 212
# Analyzing gene 116 of 212
# Analyzing gene 117 of 212
# Analyzing gene 118 of 212
# Analyzing gene 119 of 212
# Analyzing gene 120 of 212
# Analyzing gene 121 of 212
# Analyzing gene 122 of 212
# Analyzing gene 123 of 212
# Analyzing gene 124 of 212
# Analyzing gene 125 of 212
# Analyzing gene 126 of 212
# Analyzing gene 127 of 212
# Analyzing gene 128 of 212
# Analyzing gene 129 of 212
# Analyzing gene 130 of 212
# Analyzing gene 131 of 212
# Analyzing gene 132 of 212
# Analyzing gene 133 of 212
# Analyzing gene 134 of 212
# Analyzing gene 135 of 212
# Analyzing gene 136 of 212
# Analyzing gene 137 of 212
# Analyzing gene 138 of 212
# Analyzing gene 139 of 212
# Analyzing gene 140 of 212
# Analyzing gene 141 of 212
# Analyzing gene 142 of 212
# Analyzing gene 143 of 212
# Analyzing gene 144 of 212
# Analyzing gene 145 of 212
# Analyzing gene 146 of 212
# Analyzing gene 147 of 212
# Analyzing gene 148 of 212
# Analyzing gene 149 of 212
# Analyzing gene 150 of 212
# Analyzing gene 151 of 212
# Analyzing gene 152 of 212
# Analyzing gene 153 of 212
# Analyzing gene 154 of 212
# Analyzing gene 155 of 212
# Analyzing gene 156 of 212
# Analyzing gene 157 of 212
# Analyzing gene 158 of 212
# Analyzing gene 159 of 212
# Analyzing gene 160 of 212
# Analyzing gene 161 of 212
# Analyzing gene 162 of 212
# Analyzing gene 163 of 212
# Analyzing gene 164 of 212
# Analyzing gene 165 of 212
# Analyzing gene 166 of 212
# Analyzing gene 167 of 212
# Analyzing gene 168 of 212
# Analyzing gene 169 of 212
# Analyzing gene 170 of 212
# Analyzing gene 171 of 212
# Analyzing gene 172 of 212
# Analyzing gene 173 of 212
# Analyzing gene 174 of 212
# Analyzing gene 175 of 212
# Analyzing gene 176 of 212
# Analyzing gene 177 of 212
# Analyzing gene 178 of 212
# Analyzing gene 179 of 212
# Analyzing gene 180 of 212
# Analyzing gene 181 of 212
# Analyzing gene 182 of 212
# Analyzing gene 183 of 212
# Analyzing gene 184 of 212
# Analyzing gene 185 of 212
# Analyzing gene 186 of 212
# Analyzing gene 187 of 212
# Analyzing gene 188 of 212
# Analyzing gene 189 of 212
# Analyzing gene 190 of 212
# Analyzing gene 191 of 212
# Analyzing gene 192 of 212
# Analyzing gene 193 of 212
# Analyzing gene 194 of 212
# Analyzing gene 195 of 212
# Analyzing gene 196 of 212
# Analyzing gene 197 of 212
# Analyzing gene 198 of 212
# Analyzing gene 199 of 212
# Analyzing gene 200 of 212
# Analyzing gene 201 of 212
# Analyzing gene 202 of 212
# Analyzing gene 203 of 212
# Analyzing gene 204 of 212
# Analyzing gene 205 of 212
# Analyzing gene 206 of 212
# Analyzing gene 207 of 212
# Analyzing gene 208 of 212
# Analyzing gene 209 of 212
# Analyzing gene 210 of 212
# Analyzing gene 211 of 212
# Analyzing gene 212 of 212
# Analyzing gene 1 of 72
# Analyzing gene 2 of 72
# Analyzing gene 3 of 72
# Analyzing gene 4 of 72
# Analyzing gene 5 of 72
# Analyzing gene 6 of 72
# Analyzing gene 7 of 72
# Analyzing gene 8 of 72
# Analyzing gene 9 of 72
# Analyzing gene 10 of 72
# Analyzing gene 11 of 72
# Analyzing gene 12 of 72
# Analyzing gene 13 of 72
# Analyzing gene 14 of 72
# Analyzing gene 15 of 72
# Analyzing gene 16 of 72
# Analyzing gene 17 of 72
# Analyzing gene 18 of 72
# Analyzing gene 19 of 72
# Analyzing gene 20 of 72
# Analyzing gene 21 of 72
# Analyzing gene 22 of 72
# Analyzing gene 23 of 72
# Analyzing gene 24 of 72
# Analyzing gene 25 of 72
# Analyzing gene 26 of 72
# Analyzing gene 27 of 72
# Analyzing gene 28 of 72
# Analyzing gene 29 of 72
# Analyzing gene 30 of 72
# Analyzing gene 31 of 72
# Analyzing gene 32 of 72
# Analyzing gene 33 of 72
# Analyzing gene 34 of 72
# Analyzing gene 35 of 72
# Analyzing gene 36 of 72
# Analyzing gene 37 of 72
# Analyzing gene 38 of 72
# Analyzing gene 39 of 72
# Analyzing gene 40 of 72
# Analyzing gene 41 of 72
# Analyzing gene 42 of 72
# Analyzing gene 43 of 72
# Analyzing gene 44 of 72
# Analyzing gene 45 of 72
# Analyzing gene 46 of 72
# Analyzing gene 47 of 72
# Analyzing gene 48 of 72
# Analyzing gene 49 of 72
# Analyzing gene 50 of 72
# Analyzing gene 51 of 72
# Analyzing gene 52 of 72
# Analyzing gene 53 of 72
# Analyzing gene 54 of 72
# Analyzing gene 55 of 72
# Analyzing gene 56 of 72
# Analyzing gene 57 of 72
# Analyzing gene 58 of 72
# Analyzing gene 59 of 72
# Analyzing gene 60 of 72
# Analyzing gene 61 of 72
# Analyzing gene 62 of 72
# Analyzing gene 63 of 72
# Analyzing gene 64 of 72
# Analyzing gene 65 of 72
# Analyzing gene 66 of 72
# Analyzing gene 67 of 72
# Analyzing gene 68 of 72
# Analyzing gene 69 of 72
# Analyzing gene 70 of 72
# Analyzing gene 71 of 72
# Analyzing gene 72 of 72
# Analyzing gene 1 of 140
# Analyzing gene 2 of 140
# Analyzing gene 3 of 140
# Analyzing gene 4 of 140
# Analyzing gene 5 of 140
# Analyzing gene 6 of 140
# Analyzing gene 7 of 140
# Analyzing gene 8 of 140
# Analyzing gene 9 of 140
# Analyzing gene 10 of 140
# Analyzing gene 11 of 140
# Analyzing gene 12 of 140
# Analyzing gene 13 of 140
# Analyzing gene 14 of 140
# Analyzing gene 15 of 140
# Analyzing gene 16 of 140
# Analyzing gene 17 of 140
# Analyzing gene 18 of 140
# Analyzing gene 19 of 140
# Analyzing gene 20 of 140
# Analyzing gene 21 of 140
# Analyzing gene 22 of 140
# Analyzing gene 23 of 140
# Analyzing gene 24 of 140
# Analyzing gene 25 of 140
# Analyzing gene 26 of 140
# Analyzing gene 27 of 140
# Analyzing gene 28 of 140
# Analyzing gene 29 of 140
# Analyzing gene 30 of 140
# Analyzing gene 31 of 140
# Analyzing gene 32 of 140
# Analyzing gene 33 of 140
# Analyzing gene 34 of 140
# Analyzing gene 35 of 140
# Analyzing gene 36 of 140
# Analyzing gene 37 of 140
# Analyzing gene 38 of 140
# Analyzing gene 39 of 140
# Analyzing gene 40 of 140
# Analyzing gene 41 of 140
# Analyzing gene 42 of 140
# Analyzing gene 43 of 140
# Analyzing gene 44 of 140
# Analyzing gene 45 of 140
# Analyzing gene 46 of 140
# Analyzing gene 47 of 140
# Analyzing gene 48 of 140
# Analyzing gene 49 of 140
# Analyzing gene 50 of 140
# Analyzing gene 51 of 140
# Analyzing gene 52 of 140
# Analyzing gene 53 of 140
# Analyzing gene 54 of 140
# Analyzing gene 55 of 140
# Analyzing gene 56 of 140
# Analyzing gene 57 of 140
# Analyzing gene 58 of 140
# Analyzing gene 59 of 140
# Analyzing gene 60 of 140
# Analyzing gene 61 of 140
# Analyzing gene 62 of 140
# Analyzing gene 63 of 140
# Analyzing gene 64 of 140
# Analyzing gene 65 of 140
# Analyzing gene 66 of 140
# Analyzing gene 67 of 140
# Analyzing gene 68 of 140
# Analyzing gene 69 of 140
# Analyzing gene 70 of 140
# Analyzing gene 71 of 140
# Analyzing gene 72 of 140
# Analyzing gene 73 of 140
# Analyzing gene 74 of 140
# Analyzing gene 75 of 140
# Analyzing gene 76 of 140
# Analyzing gene 77 of 140
# Analyzing gene 78 of 140
# Analyzing gene 79 of 140
# Analyzing gene 80 of 140
# Analyzing gene 81 of 140
# Analyzing gene 82 of 140
# Analyzing gene 83 of 140
# Analyzing gene 84 of 140
# Analyzing gene 85 of 140
# Analyzing gene 86 of 140
# Analyzing gene 87 of 140
# Analyzing gene 88 of 140
# Analyzing gene 89 of 140
# Analyzing gene 90 of 140
# Analyzing gene 91 of 140
# Analyzing gene 92 of 140
# Analyzing gene 93 of 140
# Analyzing gene 94 of 140
# Analyzing gene 95 of 140
# Analyzing gene 96 of 140
# Analyzing gene 97 of 140
# Analyzing gene 98 of 140
# Analyzing gene 99 of 140
# Analyzing gene 100 of 140
# Analyzing gene 101 of 140
# Analyzing gene 102 of 140
# Analyzing gene 103 of 140
# Analyzing gene 104 of 140
# Analyzing gene 105 of 140
# Analyzing gene 106 of 140
# Analyzing gene 107 of 140
# Analyzing gene 108 of 140
# Analyzing gene 109 of 140
# Analyzing gene 110 of 140
# Analyzing gene 111 of 140
# Analyzing gene 112 of 140
# Analyzing gene 113 of 140
# Analyzing gene 114 of 140
# Analyzing gene 115 of 140
# Analyzing gene 116 of 140
# Analyzing gene 117 of 140
# Analyzing gene 118 of 140
# Analyzing gene 119 of 140
# Analyzing gene 120 of 140
# Analyzing gene 121 of 140
# Analyzing gene 122 of 140
# Analyzing gene 123 of 140
# Analyzing gene 124 of 140
# Analyzing gene 125 of 140
# Analyzing gene 126 of 140
# Analyzing gene 127 of 140
# Analyzing gene 128 of 140
# Analyzing gene 129 of 140
# Analyzing gene 130 of 140
# Analyzing gene 131 of 140
# Analyzing gene 132 of 140
# Analyzing gene 133 of 140
# Analyzing gene 134 of 140
# Analyzing gene 135 of 140
# Analyzing gene 136 of 140
# Analyzing gene 137 of 140
# Analyzing gene 138 of 140
# Analyzing gene 139 of 140
# Analyzing gene 140 of 140
# Analyzing gene 1 of 69
# Analyzing gene 2 of 69
# Analyzing gene 3 of 69
# Analyzing gene 4 of 69
# Analyzing gene 5 of 69
# Analyzing gene 6 of 69
# Analyzing gene 7 of 69
# Analyzing gene 8 of 69
# Analyzing gene 9 of 69
# Analyzing gene 10 of 69
# Analyzing gene 11 of 69
# Analyzing gene 12 of 69
# Analyzing gene 13 of 69
# Analyzing gene 14 of 69
# Analyzing gene 15 of 69
# Analyzing gene 16 of 69
# Analyzing gene 17 of 69
# Analyzing gene 49 of 206
# Analyzing gene 50 of 206
# Analyzing gene 51 of 206
# Analyzing gene 52 of 206
# Analyzing gene 53 of 206
# Analyzing gene 54 of 206
# Analyzing gene 55 of 206
# Analyzing gene 56 of 206
# Analyzing gene 57 of 206
# Analyzing gene 58 of 206
# Analyzing gene 59 of 206
# Analyzing gene 60 of 206
# Analyzing gene 61 of 206
# Analyzing gene 62 of 206
# Analyzing gene 63 of 206
# Analyzing gene 64 of 206
# Analyzing gene 65 of 206
# Analyzing gene 66 of 206
# Analyzing gene 67 of 206
# Analyzing gene 68 of 206
# Analyzing gene 69 of 206
# Analyzing gene 70 of 206
# Analyzing gene 71 of 206
# Analyzing gene 72 of 206
# Analyzing gene 73 of 206
# Analyzing gene 74 of 206
# Analyzing gene 75 of 206
# Analyzing gene 76 of 206
# Analyzing gene 77 of 206
# Analyzing gene 78 of 206
# Analyzing gene 79 of 206
# Analyzing gene 80 of 206
# Analyzing gene 81 of 206
# Analyzing gene 82 of 206
# Analyzing gene 83 of 206
# Analyzing gene 84 of 206
# Analyzing gene 85 of 206
# Analyzing gene 86 of 206
# Analyzing gene 87 of 206
# Analyzing gene 88 of 206
# Analyzing gene 89 of 206
# Analyzing gene 90 of 206
# Analyzing gene 91 of 206
# Analyzing gene 92 of 206
# Analyzing gene 93 of 206
# Analyzing gene 94 of 206
# Analyzing gene 95 of 206
# Analyzing gene 96 of 206
# Analyzing gene 97 of 206
# Analyzing gene 98 of 206
# Analyzing gene 99 of 206
# Analyzing gene 100 of 206
# Analyzing gene 101 of 206
# Analyzing gene 102 of 206
# Analyzing gene 103 of 206
# Analyzing gene 104 of 206
# Analyzing gene 105 of 206
# Analyzing gene 106 of 206
# Analyzing gene 107 of 206
# Analyzing gene 108 of 206
# Analyzing gene 109 of 206
# Analyzing gene 110 of 206
# Analyzing gene 111 of 206
# Analyzing gene 112 of 206
# Analyzing gene 113 of 206
# Analyzing gene 114 of 206
# Analyzing gene 115 of 206
# Analyzing gene 116 of 206
# Analyzing gene 117 of 206
# Analyzing gene 118 of 206
# Analyzing gene 119 of 206
# Analyzing gene 120 of 206
# Analyzing gene 121 of 206
# Analyzing gene 122 of 206
# Analyzing gene 123 of 206
# Analyzing gene 124 of 206
# Analyzing gene 125 of 206
# Analyzing gene 126 of 206
# Analyzing gene 127 of 206
# Analyzing gene 128 of 206
# Analyzing gene 129 of 206
# Analyzing gene 130 of 206
# Analyzing gene 131 of 206
# Analyzing gene 132 of 206
# Analyzing gene 133 of 206
# Analyzing gene 134 of 206
# Analyzing gene 135 of 206
# Analyzing gene 136 of 206
# Analyzing gene 137 of 206
# Analyzing gene 138 of 206
# Analyzing gene 139 of 206
# Analyzing gene 140 of 206
# Analyzing gene 141 of 206
# Analyzing gene 142 of 206
# Analyzing gene 143 of 206
# Analyzing gene 144 of 206
# Analyzing gene 145 of 206
# Analyzing gene 146 of 206
# Analyzing gene 147 of 206
# Analyzing gene 148 of 206
# Analyzing gene 149 of 206
# Analyzing gene 150 of 206
# Analyzing gene 151 of 206
# Analyzing gene 152 of 206
# Analyzing gene 153 of 206
# Analyzing gene 154 of 206
# Analyzing gene 155 of 206
# Analyzing gene 156 of 206
# Analyzing gene 157 of 206
# Analyzing gene 158 of 206
# Analyzing gene 159 of 206
# Analyzing gene 160 of 206
# Analyzing gene 161 of 206
# Analyzing gene 162 of 206
# Analyzing gene 163 of 206
# Analyzing gene 164 of 206
# Analyzing gene 165 of 206
# Analyzing gene 166 of 206
# Analyzing gene 167 of 206
# Analyzing gene 168 of 206
# Analyzing gene 169 of 206
# Analyzing gene 170 of 206
# Analyzing gene 171 of 206
# Analyzing gene 172 of 206
# Analyzing gene 173 of 206
# Analyzing gene 174 of 206
# Analyzing gene 175 of 206
# Analyzing gene 176 of 206
# Analyzing gene 177 of 206
# Analyzing gene 178 of 206
# Analyzing gene 179 of 206
# Analyzing gene 180 of 206
# Analyzing gene 181 of 206
# Analyzing gene 182 of 206
# Analyzing gene 183 of 206
# Analyzing gene 184 of 206
# Analyzing gene 185 of 206
# Analyzing gene 186 of 206
# Analyzing gene 187 of 206
# Analyzing gene 188 of 206
# Analyzing gene 189 of 206
# Analyzing gene 190 of 206
# Analyzing gene 191 of 206
# Analyzing gene 192 of 206
# Analyzing gene 193 of 206
# Analyzing gene 194 of 206
# Analyzing gene 195 of 206
# Analyzing gene 196 of 206
# Analyzing gene 197 of 206
# Analyzing gene 198 of 206
# Analyzing gene 199 of 206
# Analyzing gene 200 of 206
# Analyzing gene 201 of 206
# Analyzing gene 202 of 206
# Analyzing gene 203 of 206
# Analyzing gene 204 of 206
# Analyzing gene 205 of 206
# Analyzing gene 206 of 206
# Analyzing gene 1 of 204
# Analyzing gene 2 of 204
# Analyzing gene 3 of 204
# Analyzing gene 4 of 204
# Analyzing gene 5 of 204
# Analyzing gene 6 of 204
# Analyzing gene 7 of 204
# Analyzing gene 8 of 204
# Analyzing gene 9 of 204
# Analyzing gene 10 of 204
# Analyzing gene 11 of 204
# Analyzing gene 12 of 204
# Analyzing gene 13 of 204
# Analyzing gene 14 of 204
# Analyzing gene 15 of 204
# Analyzing gene 16 of 204
# Analyzing gene 17 of 204
# Analyzing gene 18 of 204
# Analyzing gene 19 of 204
# Analyzing gene 20 of 204
# Analyzing gene 21 of 204
# Analyzing gene 22 of 204
# Analyzing gene 23 of 204
# Analyzing gene 24 of 204
# Analyzing gene 25 of 204
# Analyzing gene 26 of 204
# Analyzing gene 27 of 204
# Analyzing gene 28 of 204
# Analyzing gene 29 of 204
# Analyzing gene 30 of 204
# Analyzing gene 31 of 204
# Analyzing gene 32 of 204
# Analyzing gene 33 of 204
# Analyzing gene 34 of 204
# Analyzing gene 35 of 204
# Analyzing gene 36 of 204
# Analyzing gene 37 of 204
# Analyzing gene 38 of 204
# Analyzing gene 39 of 204
# Analyzing gene 40 of 204
# Analyzing gene 41 of 204
# Analyzing gene 42 of 204
# Analyzing gene 43 of 204
# Analyzing gene 44 of 204
# Analyzing gene 45 of 204
# Analyzing gene 46 of 204
# Analyzing gene 47 of 204
# Analyzing gene 48 of 204
# Analyzing gene 49 of 204
# Analyzing gene 50 of 204
# Analyzing gene 51 of 204
# Analyzing gene 52 of 204
# Analyzing gene 53 of 204
# Analyzing gene 54 of 204
# Analyzing gene 55 of 204
# Analyzing gene 56 of 204
# Analyzing gene 57 of 204
# Analyzing gene 58 of 204
# Analyzing gene 59 of 204
# Analyzing gene 60 of 204
# Analyzing gene 61 of 204
# Analyzing gene 62 of 204
# Analyzing gene 63 of 204
# Analyzing gene 64 of 204
# Analyzing gene 65 of 204
# Analyzing gene 66 of 204
# Analyzing gene 67 of 204
# Analyzing gene 68 of 204
# Analyzing gene 69 of 204
# Analyzing gene 70 of 204
# Analyzing gene 71 of 204
# Analyzing gene 72 of 204
# Analyzing gene 73 of 204
# Analyzing gene 74 of 204
# Analyzing gene 75 of 204
# Analyzing gene 76 of 204
# Analyzing gene 77 of 204
# Analyzing gene 78 of 204
# Analyzing gene 79 of 204
# Analyzing gene 80 of 204
# Analyzing gene 81 of 204
# Analyzing gene 82 of 204
# Analyzing gene 83 of 204
# Analyzing gene 84 of 204
# Analyzing gene 85 of 204
# Analyzing gene 86 of 204
# Analyzing gene 87 of 204
# Analyzing gene 88 of 204
# ...
# -------> current pair: GCA_021090685.1_ASM2109068v1_genomic.fasta | Staphylococcus_vitulinus.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_kloosii.fasta
# -------> current pair: GCA_021090755.1_ASM2109075v1_genomic.fasta | Staphylococcus_equorum.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_chromogenes.fasta
# -------> current pair: GCA_021091005.1_ASM2109100v1_genomic.fasta | Staphylococcus_schleiferi.fasta
# -------> current pair: GCA_021090685.1_ASM2109068v1_genomic.fasta | Staphylococcus_nepalensis.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_warneri.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_arlettae.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_hominis.fasta
# -------> current pair: GCA_021090755.1_ASM2109075v1_genomic.fasta | Staphylococcus_pettenkoferi.fasta
# -------> current pair: GCA_021091005.1_ASM2109100v1_genomic.fasta | Staphylococcus_haemolyticus.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_capitis.fasta
# -------> current pair: GCA_021090685.1_ASM2109068v1_genomic.fasta | Staphylococcus_auricularis.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_xylosus.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_fleuretti.fasta
# -------> current pair: GCA_021090755.1_ASM2109075v1_genomic.fasta | Staphylococcus_saprophyticus.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_pseudintermedius.fasta
# -------> current pair: GCA_021090685.1_ASM2109068v1_genomic.fasta | Staphylococcus_caprae.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_succinus.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_sciuri.fasta
# -------> current pair: GCA_021090755.1_ASM2109075v1_genomic.fasta | Staphylococcus_vitulinus.fasta
# -------> current pair: GCA_021090685.1_ASM2109068v1_genomic.fasta | Staphylococcus_cohnii.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_warneri.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_hyicus.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_epidermidis.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_kloosii.fasta
# -------> current pair: GCA_021090755.1_ASM2109075v1_genomic.fasta | Staphylococcus_nepalensis.fasta
# -------> current pair: GCA_021090685.1_ASM2109068v1_genomic.fasta | Staphylococcus_schleiferi.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_capitis.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_pasteuri.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_aureus.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_arlettae.fasta
# -------> current pair: GCA_021090685.1_ASM2109068v1_genomic.fasta | Staphylococcus_haemolyticus.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_succinus.fasta
# -------> current pair: GCA_021090755.1_ASM2109075v1_genomic.fasta | Staphylococcus_auricularis.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_lugdunensis.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_equorum.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_xylosus.fasta
# -------> current pair: GCA_021090755.1_ASM2109075v1_genomic.fasta | Staphylococcus_caprae.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_pseudintermedius.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_hyicus.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_lentus.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_pettenkoferi.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_sciuri.fasta
# -------> current pair: GCA_021090755.1_ASM2109075v1_genomic.fasta | Staphylococcus_cohnii.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_warneri.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_pasteuri.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_chromogenes.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_saprophyticus.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_capitis.fasta
# -------> current pair: GCA_021090755.1_ASM2109075v1_genomic.fasta | Staphylococcus_schleiferi.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_epidermidis.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_lugdunensis.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_hominis.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_vitulinus.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_succinus.fasta
# -------> current pair: GCA_021090755.1_ASM2109075v1_genomic.fasta | Staphylococcus_haemolyticus.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_aureus.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_fleuretti.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_lentus.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_nepalensis.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_hyicus.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_pseudintermedius.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_equorum.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_chromogenes.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_auricularis.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_pasteuri.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_kloosii.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_warneri.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_hominis.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_pettenkoferi.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_caprae.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_lugdunensis.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_arlettae.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_capitis.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_fleuretti.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_saprophyticus.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_cohnii.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_lentus.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_xylosus.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_succinus.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_vitulinus.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_schleiferi.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_sciuri.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_chromogenes.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_kloosii.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_hyicus.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_nepalensis.fasta
# -------> current pair: GCA_021090705.1_ASM2109070v1_genomic.fasta | Staphylococcus_haemolyticus.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_hominis.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_pasteuri.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_arlettae.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_epidermidis.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_auricularis.fasta
# -------> current pair: GCA_021091045.1_ASM2109104v1_genomic.fasta | Staphylococcus_pseudintermedius.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_fleuretti.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_lugdunensis.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_aureus.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_xylosus.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_caprae.fasta
# -------> current pair: GCA_021091045.1_ASM2109104v1_genomic.fasta | Staphylococcus_warneri.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_equorum.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_sciuri.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_lentus.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_cohnii.fasta
# -------> current pair: GCA_021091045.1_ASM2109104v1_genomic.fasta | Staphylococcus_capitis.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_kloosii.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_pettenkoferi.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_chromogenes.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_epidermidis.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_schleiferi.fasta
# -------> current pair: GCA_021091045.1_ASM2109104v1_genomic.fasta | Staphylococcus_succinus.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_arlettae.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_hominis.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_saprophyticus.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_aureus.fasta
# -------> current pair: GCA_021090745.1_ASM2109074v1_genomic.fasta | Staphylococcus_haemolyticus.fasta
# -------> current pair: GCA_021091045.1_ASM2109104v1_genomic.fasta | Staphylococcus_hyicus.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_xylosus.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_fleuretti.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_vitulinus.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_equorum.fasta
# -------> current pair: GCA_021091045.1_ASM2109104v1_genomic.fasta | Staphylococcus_pasteuri.fasta
# -------> current pair: GCA_021091005.1_ASM2109100v1_genomic.fasta | Staphylococcus_pseudintermedius.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_sciuri.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_nepalensis.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_pettenkoferi.fasta
# -------> current pair: GCA_021091005.1_ASM2109100v1_genomic.fasta | Staphylococcus_warneri.fasta
# -------> current pair: GCA_021091045.1_ASM2109104v1_genomic.fasta | Staphylococcus_lugdunensis.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_kloosii.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_epidermidis.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_auricularis.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_saprophyticus.fasta
# -------> current pair: GCA_021091005.1_ASM2109100v1_genomic.fasta | Staphylococcus_capitis.fasta
# -------> current pair: GCA_021091045.1_ASM2109104v1_genomic.fasta | Staphylococcus_lentus.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_arlettae.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_aureus.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_caprae.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_vitulinus.fasta
# -------> current pair: GCA_021091005.1_ASM2109100v1_genomic.fasta | Staphylococcus_succinus.fasta
# -------> current pair: GCA_021091045.1_ASM2109104v1_genomic.fasta | Staphylococcus_chromogenes.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_xylosus.fasta
# -------> current pair: GCA_021090785.1_ASM2109078v1_genomic.fasta | Staphylococcus_equorum.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_cohnii.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_nepalensis.fasta
# -------> current pair: GCA_021091005.1_ASM2109100v1_genomic.fasta | Staphylococcus_hyicus.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_sciuri.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_schleiferi.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_auricularis.fasta
# -------> current pair: GCA_021091005.1_ASM2109100v1_genomic.fasta | Staphylococcus_pasteuri.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_epidermidis.fasta
# -------> current pair: GCA_021090725.1_ASM2109072v1_genomic.fasta | Staphylococcus_haemolyticus.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_caprae.fasta
# -------> current pair: GCA_021091005.1_ASM2109100v1_genomic.fasta | Staphylococcus_lugdunensis.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_aureus.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_cohnii.fasta
# -------> current pair: GCA_021091005.1_ASM2109100v1_genomic.fasta | Staphylococcus_lentus.fasta
# -------> current pair: GCA_021091015.1_ASM2109101v1_genomic.fasta | Staphylococcus_equorum.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_schleiferi.fasta
# -------> current pair: GCA_021091005.1_ASM2109100v1_genomic.fasta | Staphylococcus_chromogenes.fasta
# -------> current pair: GCA_021090735.1_ASM2109073v1_genomic.fasta | Staphylococcus_haemolyticus.fasta
# MODEL - ...making predictions...
# MODEL - ...predictions are done!...
